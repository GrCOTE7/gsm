# %% [markdown]
# <h3 align='right'><span style="text-decoration:none;"><a href="./0001_TOC.md" title="Table Of Content">TOC</a></span></h3>
#
# <h1 align='center'>GIT DEEP</h1>
#
# <h3 align="center">
#   <a href="./0206_VSC_STDT3.md">← 0205_VSC_STDT2</a>
#
#   <a href="./0301_GIT_DEEP.md">0300_GIT_DEEP →</a>
# </h3>

# %% [markdown]
# ## GIT Approfondi

# %% [markdown]
# # ❌ To be continued... 🚧

# %% [markdown]
# ## Rappel
#
# <div align="center">
#   <a href="./imgs/301_GIT.png" target="_blank">
#     <img src="./imgs/301_GIT.png" width="300">
#   </a>
# </div>

# %% [markdown]
# * [ ] To be continued... 🚧

# %%
a=2
b=3
print(a+b)
# Out:
# 5

# %% [markdown]
# ❌ On a déjà eût ce cas, et on l'avait [résolu directement sur GH](XXX)
