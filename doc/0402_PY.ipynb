# %% [markdown]
# # Python - Bases

# %% [markdown]
# ## Toujours garder l'objectif à l'esprit

# %% [markdown]
# ### Rappel : Le codage, c'est :

# %% [markdown]
# ```mermaid
# graph LR
#   A[**Objectif**]---->B{Plantage ?};
#   B---->|Oui| C[Investigations...];
#   C--->D[Debugage];
#   D-->B;
#   B------>|Non| E[Succès → Objectif atteint !];
# ```

# %% [markdown]
# ### Et dans notre projet :

# %% [markdown]
# $$
# \text{Dev du contributeur GSM} =
# \Bigg(
# \underbrace{
#   \Big(
#     \underbrace{
#       (
#         \underbrace{\text{Codage} + \text{Commit}}_{\text{Unité de travail}}
#       )\times x
#     }_{\text{Itérations locales}}
#     + \text{Push}
#   \Big)\times y
#   + \text{PR}
# \Bigg)
# }_{\text{Cycle complet}}
# \times z
# $$

# %% [markdown]
# * [ ] To be continued... 🚧

# %% [markdown]
# \[
# \text{Dev du contributeur GSM} =
# \underbrace{
# \begin{aligned}
# \Big(
#     &\underbrace{
#         \left(
#             (\text{Codage} + \text{Commit})x
#             + \text{Push}
#         \right)y
#         + \text{PR}
#     }_{\text{Itérations locales}}
# \Big) z
# \end{aligned}
# }_{\text{Cycle complet}}
# \]

# %% [markdown]
# $$
# \text{Dev du contributeur GSM} =
# \underbrace{
# \Bigg(
#   \underbrace{
#     \Big(
#       (\text{Codage} + \text{Commit})\times x
#       + \text{Push}
#     \Big)\times y
#     + \text{PR}
#   }_{\text{Itérations locales}}
# \Bigg)\times z
# }_{\text{Cycle complet}}
# $$

# %% [markdown]
# $$
# \text{Dev du contributeur GSM} =
# \underbrace{
# \Bigg(
#   \underbrace{
#     \Big(
#       \underbrace{
#         (\text{Codage} + \text{Commit})
#       }_{\text{Unité de travail}}
#       \times x
#       + \text{Push}
#     \Big)\times y
#     + \text{PR}
#   }_{\text{Itérations locales}}
# \Bigg)\times z
# }_{\text{Cycle complet}}
# $$
